# %%
import pandas as pd
import gmaps
import requests
import json
import pprint
import googlemaps

from config import g_key

gmaps.configure(api_key=g_key)

# %%
location="/Users/buraksavassahin/API Applications/weather/output/500city.csv"

# %%
df=pd.read_csv(location)

# %%
df
# Out:
#             City_Name  Latitude  Longtitude  Max. Temperature  Humidity  \
# 0           Kapchorwa      1.40       34.45            59.108        67
# 1        Punta Arenas    -53.15      -70.92            46.400        65
# 2             Mataura    -46.19      168.86            57.992        83
# 3             Rikitea    -23.12     -134.97            76.478        77
# 4             Chicama     -7.84      -79.15            66.200        88
# ..                ...       ...         ...               ...       ...
# 571         Neyshabur     36.21       58.80            33.638        83
# 572      Brigham City     41.51     -112.02            35.996        80
# 573  Krasnorechenskiy     44.63      135.35            12.056        90
# 574          Mabaruma      8.20      -59.78            72.986        98
# 575               Voh    -20.97      164.70            81.302        63
#
#      Cloudiness  Wind_Speed Country        Date
# 0             0        1.94      UG  1608515852
# 1            77        8.20      CL  1608515708
# 2           100        3.13      NZ  1608515699
# 3             3        9.36      PF  1608515696
# 4            20        4.10      PE  1608515768
# ..          ...         ...     ...         ...
# 571          55        0.50      IR  1608515927
# 572          90        1.50      US  1608515659
# 573          73        3.17      RU  1608515927
# 574          30        1.18      GY  1608515927
# 575          74        2.56      NC  1608515751
#
# [576 rows x 9 columns]

# %%
humidity=df["Humidity"].astype(float)

# %%
locations=df[["Latitude","Longtitude"]]

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius=1)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
ideal_weather=df.loc[(df["Max. Temperature"]>75 ) & (df["Max. Temperature"]<80) & 
                     (df["Wind_Speed"]<5) & (df["Cloudiness"]<30), 
                     ["City_Name","Country","Latitude","Longtitude","Max. Temperature","Wind_Speed","Cloudiness"]]
ideal_weather=ideal_weather.sort_values(by=["Max. Temperature","Wind_Speed"], ascending=False)
ideal_weather
# Out:
#        City_Name Country  Latitude  Longtitude  Max. Temperature  Wind_Speed  \
# 398  Robertsport      LR      6.75      -11.37            79.538        1.73
# 251         Poum      NC    -20.23      164.02            79.268        4.14
# 212       Trairi      BR     -3.28      -39.27            79.106        4.27
# 559      Fayaoué      NC    -20.65      166.53            79.052        4.19
# 491    Road Town      VG     18.42      -64.62            78.998        1.79
# 554         Esim      GH      4.87       -2.24            78.584        2.44
# 376      Iralaya      HN     15.00      -83.23            77.990        3.14
# 503     Buchanan      LR      5.88      -10.05            77.936        1.99
# 357       Harper      LR      4.38       -7.72            77.846        2.69
# 476     Maragogi      BR     -9.01      -35.22            77.234        4.71
# 235     Belmonte      BR    -15.86      -38.88            77.000        1.50
# 536      Berbera      SO     10.44       45.01            76.676        3.50
# 446     Londrina      BR    -23.31      -51.16            75.200        2.10
# 431    Inhambane      MZ    -23.86       35.38            75.056        3.39
#
#      Cloudiness
# 398           2
# 251          24
# 212          13
# 559          10
# 491           7
# 554           0
# 376          17
# 503          10
# 357          12
# 476           8
# 235           0
# 536          23
# 446           0
# 431          28

# %%
coordinates=ideal_weather[["Latitude","Longtitude"]]
coordinates_list=coordinates.values.tolist()
coordinates_list
# Out:
# [[6.75, -11.37],
#  [-20.23, 164.02],
#  [-3.28, -39.27],
#  [-20.65, 166.53],
#  [18.42, -64.62],
#  [4.87, -2.24],
#  [15.0, -83.23],
#  [5.88, -10.05],
#  [4.38, -7.72],
#  [-9.01, -35.22],
#  [-15.86, -38.88],
#  [10.44, 45.01],
#  [-23.31, -51.16],
#  [-23.86, 35.38]]

# %%
target_coordinates='6.75,-11.37'
target_radius = 5000
target_type = "hotel"
key="AIzaSyA6SKkyvoJ6Fn6BlI8eg28bTW1uBVsFTKQ"

params = {
    "radius": target_radius,
    "type": target_type,
    "key": key}

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response = requests.get(base_url, params=params)
print(response)
# Out:
# <Response [200]>

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
target_radius = 5000
target_type = "lodging"
key="AIzaSyA6SKkyvoJ6Fn6BlI8eg28bTW1uBVsFTKQ"
params = {
    "radius": target_radius,
    "type": target_type,
    "key": key}

for index, row in ideal_weather.iterrows():
    
    lat = row["Latitude"]
    lng = row["Longtitude"]
    
    params["location"] = f"{lat},{lng}"
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    

    
    hotel_name = requests.get(base_url, params=params)
    hotel_name = hotel_name.json()
    
    try:
        ideal_weather.loc[index, "Hotel Name"] = hotel_name["results"][0]["name"]
        ideal_weather.loc[index, "Hotel_Latitude"] = hotel_name["results"][0]["geometry"]["location"]["lat"]
        ideal_weather.loc[index, "Hotel_Longtitude"] = hotel_name["results"][0]["geometry"]["location"]["lng"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

# %%
id_df=ideal_weather[["Hotel Name","City_Name","Country","Max. Temperature","Wind_Speed","Cloudiness",
                     "Latitude","Longtitude","Hotel_Latitude","Hotel_Longtitude"]]
id_df.fillna(1)
# Out:
#                                          Hotel Name    City_Name Country  \
# 398                                Kwepunha Retreat  Robertsport      LR
# 251                                     Gîte kajeon         Poum      NC
# 212                                  janelas do mar       Trairi      BR
# 559                          Chez Dydyce Guesthouse      Fayaoué      NC
# 491  ZINGARA 76ft Catamaran, full crew-all included    Road Town      VG
# 554                       AXIM BEACH RESORT AND SPA         Esim      GH
# 376                         Iglesia morava renovada      Iralaya      HN
# 503                             Kamaneahn Hotel Inc     Buchanan      LR
# 357                                     Screensaver       Harper      LR
# 476        Salinas do Maragogi All Inclusive Resort     Maragogi      BR
# 235                     Pousada Monte Carmelo O Pão     Belmonte      BR
# 536                                     Damal Hotel      Berbera      SO
# 446                       Hotel Crillon em Londrina     Londrina      BR
# 431                                          Oceano    Inhambane      MZ
#
#      Max. Temperature  Wind_Speed  Cloudiness  Latitude  Longtitude  \
# 398            79.538        1.73           2      6.75      -11.37
# 251            79.268        4.14          24    -20.23      164.02
# 212            79.106        4.27          13     -3.28      -39.27
# 559            79.052        4.19          10    -20.65      166.53
# 491            78.998        1.79           7     18.42      -64.62
# 554            78.584        2.44           0      4.87       -2.24
# 376            77.990        3.14          17     15.00      -83.23
# 503            77.936        1.99          10      5.88      -10.05
# 357            77.846        2.69          12      4.38       -7.72
# 476            77.234        4.71           8     -9.01      -35.22
# 235            77.000        1.50           0    -15.86      -38.88
# 536            76.676        3.50          23     10.44       45.01
# 446            75.200        2.10           0    -23.31      -51.16
# 431            75.056        3.39          28    -23.86       35.38
#
#      Hotel_Latitude  Hotel_Longtitude
# 398        6.757024        -11.372110
# 251      -20.231771        164.023059
# 212       -3.269698        -39.268476
# 559      -20.634801        166.547021
# 491       18.427339        -64.618406
# 554        4.867164         -2.233979
# 376       14.997715        -83.222204
# 503        5.896306        -10.026451
# 357        4.374686         -7.719573
# 476       -9.027939        -35.227731
# 235      -15.859126        -38.878880
# 536       10.440097         45.008984
# 446      -23.314628        -51.160383
# 431      -23.861426         35.346690

# %%
#places_data = response.json()

print(json.dumps(hotel_name, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwIDN4yHZx3sYj0yllJMOoIKFl__rkZmjhM-5d3DL9zAFqa9oquNvcJ-2QpM_Gb4TOf-CFg_XFAiaiksqZOGYJdKLf22snWgxEfKwcgymK-oopVOUPhdzrWXR3MNJcRefxzxUV5YJyYAKLCplZ33R2tmSLl4a4teJ7RhYayq5E-5UaagKYOTaG7_unAPAORV2bxGebofVTL_rBGfhIhxw5KIzpB-EUjvtqd9LM9aBLgR3k0SUaUYjOdfwGgXeewPQH9hY0U72JPP5bvnMje-HVfOtfj-jTzzkYcULNapwr6UT-sSh6U3U9adhj7TFtrRisC9dJas7Z77LpxM6exw2T6-hGBqAfz3A5MJJWSFX7MlOJ_4lqywxB5Y7YZMHfnEb6vmQfG-7gwhhUwxMdxpx5qy-jl7vS7WAWpEfClNaek-NUTlJYxdy_Tn",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.8614259,
#                     "lng": 35.3466896
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8600636197085,
#                         "lng": 35.3481416302915
#                     },
#                     "southwest": {
#                         "lat": -23.8627615802915,
#                         "lng": 35.3454436697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Oceano",
#             "photos": [
#                 {
#                     "height": 2048,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112530961371847235177\">herminio chamusso</a>"
#                     ],
#                     "photo_reference": "ATtYBwK9k5riGHjehPp0UF70KymhVD3xkKugchagwoxqB3u9ZUC66NUZ60hr3MIfuTLHAoRsZ3sse4iRoHr1QX1JHKbYmF2O7E4Aa5kDrGK56i2mxu1icbmwbjpAPTJmbA2PRaW5t9Af-mjdMHueJ_BztrvBkJRRd8JB5h5ETtRGqMip0nRf",
#                     "width": 1536
#                 }
#             ],
#             "place_id": "ChIJ_e_dzMzPIR8R59sZefYXUXM",
#             "plus_code": {
#                 "compound_code": "48QW+CM Maxixe, Mozambique",
#                 "global_code": "5G8Q48QW+CM"
#             },
#             "rating": 3.4,
#             "reference": "ChIJ_e_dzMzPIR8R59sZefYXUXM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 51,
#             "vicinity": "Maxixe"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.8675703,
#                     "lng": 35.385139
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8662393697085,
#                         "lng": 35.3865848302915
#                     },
#                     "southwest": {
#                         "lat": -23.8689373302915,
#                         "lng": 35.3838868697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "O Rouxinol",
#             "photos": [
#                 {
#                     "height": 3264,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102124715764095818979\">idalencio david</a>"
#                     ],
#                     "photo_reference": "ATtYBwIpCXHqvEGSsw3P50kdR7-HnF58H-CAsZassbPF_QwZb6k-0funRrogrSvLsvTT11Zx1PkrRedirHjo47rmLbtGJi6AkRx0ZIz60D1Y2kuI6dJz2Tt07S8d2-P5lIdwrzhEdy3qN-eRUtbwiHCzwyP5t8PLvtP9_FeDscGtzRs8oZXL",
#                     "width": 2448
#                 }
#             ],
#             "place_id": "ChIJRf06gAHQIR8RdVbEQr1JV5Y",
#             "plus_code": {
#                 "compound_code": "49JP+X3 Inhambane, Mozambique",
#                 "global_code": "5G8Q49JP+X3"
#             },
#             "rating": 3.6,
#             "reference": "ChIJRf06gAHQIR8RdVbEQr1JV5Y",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 26,
#             "vicinity": "749 Avenida Revolu\u00e7\u00e3o, Inhambane"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.8622222,
#                     "lng": 35.37833329999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8609581697085,
#                         "lng": 35.3797374302915
#                     },
#                     "southwest": {
#                         "lat": -23.8636561302915,
#                         "lng": 35.3770394697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Casa Do Capit\u00e3o",
#             "photos": [
#                 {
#                     "height": 1836,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116919962357974986801\">Moises Mucelo</a>"
#                     ],
#                     "photo_reference": "ATtYBwLKRsERCXoI1M6zBr4TewM8m_M0D_7d6y2sbfBYTTeuvEjKw8ZcUH1ecrUAsCmiuCeOmuu2wzRlr7-4kLHIpBN0GnWcljxrTfScjK-YpzP4O_OiBymhw63MrARKnUtJlJEb0pJSWIZFjkRiU2_ddPnj5bPrP8KJzwiDuKJONo3DYHV8",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJeSHmXOPPIR8RpTpiuavbcMI",
#             "plus_code": {
#                 "compound_code": "49QH+48 Inhambane, Mozambique",
#                 "global_code": "5G8Q49QH+48"
#             },
#             "rating": 4.3,
#             "reference": "ChIJeSHmXOPPIR8RpTpiuavbcMI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 334,
#             "vicinity": "Balane 1, Av. Maguiguana, Inhambane"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.8658637,
#                     "lng": 35.3825029
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8645251197085,
#                         "lng": 35.3839453302915
#                     },
#                     "southwest": {
#                         "lat": -23.8672230802915,
#                         "lng": 35.3812473697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Inhambane",
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108867575667693125153\">Shazmin</a>"
#                     ],
#                     "photo_reference": "ATtYBwKJvAq1_K1TG8EDIkn3xB3-h6eNf3kIgucWw-WAAjJwY2RDxURWj5VqLqPN78O6UG5r54SDV0cldxpbNV8tPXZ3mCIPMJ2k5EhidIJcFryrAvu1eIDwZtsMjo-qgKuAyu88kKpAlkGkdIsFNESpOjfCdhZsdapdYEPdyn7n-AchXrZW",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJu7IRwQvRIR8RDo4ERATMCD8",
#             "plus_code": {
#                 "compound_code": "49MM+M2 Inhambane, Mozambique",
#                 "global_code": "5G8Q49MM+M2"
#             },
#             "rating": 3,
#             "reference": "ChIJu7IRwQvRIR8RDo4ERATMCD8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4,
#             "vicinity": "Avenida Da Vigilancia, Inhambane"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.8662153,
#                     "lng": 35.3826756
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8648681197085,
#                         "lng": 35.3840455802915
#                     },
#                     "southwest": {
#                         "lat": -23.8675660802915,
#                         "lng": 35.3813476197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Zavala - Quissico",
#             "place_id": "ChIJX3WWh9DRIR8RYowDlG5Z4zE",
#             "plus_code": {
#                 "compound_code": "49MM+G3 Inhambane, Mozambique",
#                 "global_code": "5G8Q49MM+G3"
#             },
#             "rating": 2,
#             "reference": "ChIJX3WWh9DRIR8RYowDlG5Z4zE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Inhambane"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.8662153,
#                     "lng": 35.3826756
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8648681197085,
#                         "lng": 35.3840455802915
#                     },
#                     "southwest": {
#                         "lat": -23.8675660802915,
#                         "lng": 35.3813476197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Edio Artur Guifutela",
#             "place_id": "ChIJtRgiZrnRIR8R129NfStvvoM",
#             "plus_code": {
#                 "compound_code": "49MM+G3 Inhambane, Mozambique",
#                 "global_code": "5G8Q49MM+G3"
#             },
#             "reference": "ChIJtRgiZrnRIR8R129NfStvvoM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Inhambane"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.8662153,
#                     "lng": 35.3826756
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8648681197085,
#                         "lng": 35.3840455802915
#                     },
#                     "southwest": {
#                         "lat": -23.8675660802915,
#                         "lng": 35.3813476197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Manguela Resort",
#             "place_id": "ChIJzWpoU6zRIR8Rdo3_cXhC4ms",
#             "plus_code": {
#                 "compound_code": "49MM+G3 Inhambane, Mozambique",
#                 "global_code": "5G8Q49MM+G3"
#             },
#             "reference": "ChIJzWpoU6zRIR8Rdo3_cXhC4ms",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Avenida de Maguiguana, En5"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.8662153,
#                     "lng": 35.3826756
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8648681197085,
#                         "lng": 35.3840455802915
#                     },
#                     "southwest": {
#                         "lat": -23.8675660802915,
#                         "lng": 35.3813476197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Vila de Ferias Andy",
#             "place_id": "ChIJkwQmZpHRIR8R7jkWAx71_cg",
#             "plus_code": {
#                 "compound_code": "49MM+G3 Inhambane, Mozambique",
#                 "global_code": "5G8Q49MM+G3"
#             },
#             "reference": "ChIJkwQmZpHRIR8R7jkWAx71_cg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Inhambane"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.8662153,
#                     "lng": 35.3826756
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8648681197085,
#                         "lng": 35.3840455802915
#                     },
#                     "southwest": {
#                         "lat": -23.8675660802915,
#                         "lng": 35.3813476197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Gin & Jack Beach House",
#             "photos": [
#                 {
#                     "height": 3040,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118057557781294643059\">Gin and Jack</a>"
#                     ],
#                     "photo_reference": "ATtYBwI89dxtdpzWMI5FyAq4xGHcyn72KDMv2z8N3ueQcx8ql0ZI7xXypBdUyjcYZuUaU6QQ_QLp41yA9q7wDxwqz2GcAkvUMb8LlkYD0SXa3xULkIrYt6cfaCmU2sRHzv9Mrb1cAstKGrIFf7_JCHm98_2X4cuQJOFWm0zA3OrmqsUHuykb",
#                     "width": 4056
#                 }
#             ],
#             "place_id": "ChIJg_AeEB_RIR8RMzuw5L4gBtA",
#             "plus_code": {
#                 "compound_code": "49MM+G3 Inhambane, Mozambique",
#                 "global_code": "5G8Q49MM+G3"
#             },
#             "reference": "ChIJg_AeEB_RIR8RMzuw5L4gBtA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Inhambane"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.866003,
#                     "lng": 35.383373
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8646595197085,
#                         "lng": 35.3847238802915
#                     },
#                     "southwest": {
#                         "lat": -23.8673574802915,
#                         "lng": 35.3820259197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Dhow Bay Villa",
#             "place_id": "ChIJhXM0cgLQIR8RTRvFp6ILPuU",
#             "plus_code": {
#                 "compound_code": "49MM+H8 Inhambane, Mozambique",
#                 "global_code": "5G8Q49MM+H8"
#             },
#             "rating": 5,
#             "reference": "ChIJhXM0cgLQIR8RTRvFp6ILPuU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Barra Peninsula"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.866003,
#                     "lng": 35.383373
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8646595197085,
#                         "lng": 35.3847238802915
#                     },
#                     "southwest": {
#                         "lat": -23.8673574802915,
#                         "lng": 35.3820259197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Dhow Bay Villa",
#             "place_id": "ChIJhXM0cgLQIR8Ro5II1eWCSLU",
#             "plus_code": {
#                 "compound_code": "49MM+H8 Inhambane, Mozambique",
#                 "global_code": "5G8Q49MM+H8"
#             },
#             "reference": "ChIJhXM0cgLQIR8Ro5II1eWCSLU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Barra Peninsula"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.8671243,
#                     "lng": 35.3831713
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8658668697085,
#                         "lng": 35.3844703802915
#                     },
#                     "southwest": {
#                         "lat": -23.8685648302915,
#                         "lng": 35.3817724197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel",
#             "photos": [
#                 {
#                     "height": 4160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112607736398094956971\">Alberto F\u00e9lix Macovela</a>"
#                     ],
#                     "photo_reference": "ATtYBwJIF8XIV1cx_-wHzvYojXpmGnq5rMEiCkqNxRrEuaH_HYQp-kyXcaM6YL0Lg3_No8a8DS-McblEnedPFjdEkJhRgokzNiW-Byf3LKH-idhSAH5twSrxR7bywuRj-w7g0bT7wXULwItFWLYmdwKJGH0sIJ98dlWiLIr3infb4u2lZkho",
#                     "width": 3120
#                 }
#             ],
#             "place_id": "ChIJ7yXifgLQIR8Rcz4YszhBAKI",
#             "plus_code": {
#                 "compound_code": "49MM+57 Inhambane, Mozambique",
#                 "global_code": "5G8Q49MM+57"
#             },
#             "rating": 4,
#             "reference": "ChIJ7yXifgLQIR8Rcz4YszhBAKI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 25,
#             "vicinity": "Inhambane"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.8646353,
#                     "lng": 35.3871138
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8635377197085,
#                         "lng": 35.3882424302915
#                     },
#                     "southwest": {
#                         "lat": -23.8662356802915,
#                         "lng": 35.3855444697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Escola Superior de Hotelaria and Tourismo",
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116152400153312717630\">C\u00e1iton de Jesus Jos\u00e9</a>"
#                     ],
#                     "photo_reference": "ATtYBwL5fQMzwmvY-tMf85Zpw1crtofnaQl9miKsOdYOOE3R1s8ZKlaXDdsgVgiasQURGHg0glVRRPOb6YDMjH_yI7p5s9QE5VlesqIxC69DF2LQslnDvPI2E_yQMJJv9ftFeKLhCbqxxQ6Sxm7hCTwyf0rrL86FwUENZ_8Tz_Z0ZCPub_D4",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJObeP1wHQIR8RlSw1VZyl3Zg",
#             "plus_code": {
#                 "compound_code": "49PP+4R Inhambane, Mozambique",
#                 "global_code": "5G8Q49PP+4R"
#             },
#             "rating": 3.9,
#             "reference": "ChIJObeP1wHQIR8RlSw1VZyl3Zg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 179,
#             "vicinity": "Inhambane"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.8690919,
#                     "lng": 35.38417529999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8676555697085,
#                         "lng": 35.38554328029149
#                     },
#                     "southwest": {
#                         "lat": -23.8703535302915,
#                         "lng": 35.38284531970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Terminal de Autocarros da Cidade de Inhambane",
#             "place_id": "ChIJ5zksFD_RIR8RLyaXtZxzlx0",
#             "plus_code": {
#                 "compound_code": "49JM+9M Inhambane, Mozambique",
#                 "global_code": "5G8Q49JM+9M"
#             },
#             "reference": "ChIJ5zksFD_RIR8RLyaXtZxzlx0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Inhambane"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.86959939999999,
#                     "lng": 35.382789
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8682593697085,
#                         "lng": 35.3841158802915
#                     },
#                     "southwest": {
#                         "lat": -23.8709573302915,
#                         "lng": 35.3814179197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Madina's Guest House",
#             "place_id": "ChIJ3Y47zp3RIR8R7qd6QLn_EfI",
#             "plus_code": {
#                 "compound_code": "49JM+54 Inhambane, Mozambique",
#                 "global_code": "5G8Q49JM+54"
#             },
#             "reference": "ChIJ3Y47zp3RIR8R7qd6QLn_EfI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Avenida Acordos de Lusaka, Inhambane"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.8707181,
#                     "lng": 35.3836893
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8695284697085,
#                         "lng": 35.3849302302915
#                     },
#                     "southwest": {
#                         "lat": -23.8722264302915,
#                         "lng": 35.3822322697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pomene Beach Camp",
#             "place_id": "ChIJgV72V1jRIR8R53CgqXahj7s",
#             "plus_code": {
#                 "compound_code": "49HM+PF Inhambane, Mozambique",
#                 "global_code": "5G8Q49HM+PF"
#             },
#             "rating": 4,
#             "reference": "ChIJgV72V1jRIR8R53CgqXahj7s",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3,
#             "vicinity": "1 Oceanview Drive Pomene"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.87077099999999,
#                     "lng": 35.388927
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8694811197085,
#                         "lng": 35.39021998029149
#                     },
#                     "southwest": {
#                         "lat": -23.8721790802915,
#                         "lng": 35.3875220197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Villa Luiza Boutique Hotel",
#             "place_id": "ChIJf856FAfQIR8RifVZOSzUR3w",
#             "plus_code": {
#                 "compound_code": "49HQ+MH Inhambane, Mozambique",
#                 "global_code": "5G8Q49HQ+MH"
#             },
#             "reference": "ChIJf856FAfQIR8RifVZOSzUR3w",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Avenida Do Trabalho, Inhambane"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.8707707,
#                     "lng": 35.3889281
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8694811197085,
#                         "lng": 35.3902207802915
#                     },
#                     "southwest": {
#                         "lat": -23.8721790802915,
#                         "lng": 35.3875228197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Villa Luiza",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109475063867257021523\">Villa Luiza</a>"
#                     ],
#                     "photo_reference": "ATtYBwJjRX6LfHPLNXVdPsbjMioifdBjnnDo04wHLlqaifZKpoh5PMHj-aAFf2u76ilIzTWgHG8doVZF5e65N4zolQLG7VYCXVmyyYVW1k2LVj1_zeN1y3Maf9ss2dzZBvXU_YNfoMl0Dzl5orzVP79PYlBEdjWtSEWZBvuxym4XUogx6LVA",
#                     "width": 6000
#                 }
#             ],
#             "place_id": "ChIJ5dBH3U7RIR8RWrWxEayyBNc",
#             "plus_code": {
#                 "compound_code": "49HQ+MH Inhambane, Mozambique",
#                 "global_code": "5G8Q49HQ+MH"
#             },
#             "rating": 3.8,
#             "reference": "ChIJ5dBH3U7RIR8RWrWxEayyBNc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 14,
#             "vicinity": "36 Avenida de Trabalho, Inhambane"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.8708034,
#                     "lng": 35.3889488
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.8695091697085,
#                         "lng": 35.39024588029149
#                     },
#                     "southwest": {
#                         "lat": -23.8722071302915,
#                         "lng": 35.3875479197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "VILA LUIZA Boutique Hotel",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105377433968223373407\">VILA LUIZA</a>"
#                     ],
#                     "photo_reference": "ATtYBwI0r0L7Q5aWsj0WKeV0GjkNexOvGl2I4wnjLVVMuWplJQPqNSnp2oGkdsVug3Nv3KvQk4nTBOYrAt88eTDBntGZpEPYEb8at_rVT3AXOyKu9YL9X9j6-N-dVlas6y_ZCwqGSOan-c3EdMpac4t-mC9pJEUUtPkPc2meRKOsbOdifrdY",
#                     "width": 5184
#                 }
#             ],
#             "place_id": "ChIJH3IPO_PRIR8RDMfkjAbm8hc",
#             "plus_code": {
#                 "compound_code": "49HQ+MH Inhambane, Mozambique",
#                 "global_code": "5G8Q49HQ+MH"
#             },
#             "rating": 4.1,
#             "reference": "ChIJH3IPO_PRIR8RDMfkjAbm8hc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 31,
#             "vicinity": "Inhambane Inhambane c\u00e9u, Inhambane"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -23.8700071,
#                     "lng": 35.3904568
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.86866136970849,
#                         "lng": 35.39178298029149
#                     },
#                     "southwest": {
#                         "lat": -23.8713593302915,
#                         "lng": 35.3890850197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Casa Jensen",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115417504935283230364\">Rodrigues Jaime Cotela</a>"
#                     ],
#                     "photo_reference": "ATtYBwIcP9qHSnjM74djM6ki53IIohe5xkEWKo9JErkElO4GS_kMO1r3t5PvI96c9fmIg7yxnkv1MIb265EwW8Gy6olN8NZ1MaHHBKtx6R92ITs5WjM66h-foMqB_NCx8KyQEzd2P_tpWGDmJp0SdcSOca_PcAOuTHB-9Isvw1flqdvvUU2F",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJS0jtXwfQIR8Rx_CQ0zuFi2Y",
#             "plus_code": {
#                 "compound_code": "49HR+X5 Inhambane, Mozambique",
#                 "global_code": "5G8Q49HR+X5"
#             },
#             "rating": 3.9,
#             "reference": "ChIJS0jtXwfQIR8Rx_CQ0zuFi2Y",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 119,
#             "vicinity": "Inhambane"
#         }
#     ],
#     "status": "OK"
# }

# %%
esim_coordinates=(4.87,-2.24)

info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City_Name}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""

hotel_info = [info_box_template.format(**row) for index, row in id_df.iterrows()]
locations = id_df[["Hotel_Latitude", "Hotel_Longtitude"]]

markers=gmaps.marker_layer(locations)
marker_layer = gmaps.marker_layer(locations,info_box_content=hotel_info)
fig = gmaps.figure(map_type="TERRAIN",center=esim_coordinates, zoom_level=12)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
